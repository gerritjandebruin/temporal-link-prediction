# %%
# %cd /scratch/bruingjde/SNAM2021-code/

import os
import typing

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import sklearn.linear_model
import sklearn.model_selection
import sklearn.metrics
import sklearn.pipeline
import sklearn.preprocessing
from tqdm.auto import tqdm

import tlp
# Out:
# /scratch/bruingjde/SNAM2021-code

# %%
tlp.Experiment._fields
# Out:
# ('feature',
#  'time_aware',
#  'aggregation_strategy',
#  'time_strategy',
#  'nodepair_strategy')

# %%
filename = 'auc_all_features.float'
features = None

# %%
entries = sorted(os.scandir('data'), key=lambda x: x.name)

X_all = dict()
pipe_all = dict()
auc_all = dict()
cols_all = dict()

for entry in entries:
  index = int(entry.name)
  X_dict = dict()

  # If features are not calculated yet, quit.
  if not os.path.isdir(os.path.join(entry.path, 'features')): 
    tlp.print_status(f'#{index} No feature construction yet')
    continue

  tlp.print_status(f'#{index}')
  # Get all calculated features.
  for file in os.scandir(os.path.join(entry.path, 'features')):
    if features is None or file.name in features:
      X_dict.update(joblib.load(file.path))
      
  X = pd.DataFrame(X_dict)
  cols = list(X_dict.keys())

  # Get targets
  y = np.load(os.path.join(entry.path, 'targets_sampled.npy'))

  # Fit and predict pipeline
  X_train, X_test, y_train, y_test = (
    sklearn.model_selection.train_test_split(X, y))
  pipe = sklearn.pipeline.make_pipeline(
    sklearn.preprocessing.StandardScaler(),
    sklearn.linear_model.LogisticRegression(max_iter=10000)) # type: ignore
  pipe.fit(X_train, y_train)
  auc = sklearn.metrics.roc_auc_score(
    y_true=y_test, y_score=pipe.predict_proba(X_test)[:,1]) # type: ignore
  
  X_all[index] = pd.DataFrame(X_dict)  
  cols_all[index] = cols
  pipe_all[index] = pipe
  auc_all[index] = auc
# Out:
# 2021-02-26 11:34:20.303968 #1
# 2021-02-26 11:34:21.118247 #2
# 2021-02-26 11:34:21.934172 #3
# 2021-02-26 11:34:22.421441 #4
# 2021-02-26 11:34:23.163326 #5
# 2021-02-26 11:34:24.018804 #6
# 2021-02-26 11:34:25.082042 #7
# 2021-02-26 11:34:25.859987 #8
# 2021-02-26 11:34:26.660716 #9
# 2021-02-26 11:34:27.508427 #10 No feature construction yet
# 2021-02-26 11:34:27.509066 #11 No feature construction yet
# 2021-02-26 11:34:27.509273 #12
# 2021-02-26 11:34:28.335411 #13
# 2021-02-26 11:34:29.491228 #14
# 2021-02-26 11:34:30.296896 #16
# 2021-02-26 11:34:30.997888 #18
# 2021-02-26 11:34:31.735205 #19
# 2021-02-26 11:34:32.140473 #20
# 2021-02-26 11:34:32.837558 #21
# 2021-02-26 11:34:34.055145 #22
# 2021-02-26 11:34:34.676440 #23
# 2021-02-26 11:34:35.362508 #24 No feature construction yet
# 2021-02-26 11:34:35.362808 #25 No feature construction yet
# 2021-02-26 11:34:35.363127 #28
# 2021-02-26 11:34:36.084276 #29
# 2021-02-26 11:34:36.778726 #30
# 2021-02-26 11:34:37.669132 #31

# %%
dfs = []
for idx in tqdm(X_all.keys()):
  df = pd.DataFrame(cols_all[idx])
  df['rank'] = np.mean(scipy.stats.rankdata(pipe_all[idx]['logisticregression'].coef_[0] * X_all[idx].values, axis=1), axis=0)
  df['dataset'] = idx
  dfs.append(df)
# Out:
# 100%|██████████| 23/23 [00:18<00:00,  1.23it/s]

# %%
df = pd.concat(dfs)

# %%
df.groupby([col for col in df.columns if col not in ['rank', 'dataset']])['rank'].mean().sort_values().reset_index()
# Out:
#    feature  time_aware aggregation_strategy time_strategy nodepair_strategy  \
# 0       NA        True                  sum           lin               sum
# 1       NA        True                  sum          sqrt               sum
# 2       NA        True                  sum          sqrt               max
# 3       NA        True                  sum           lin               max
# 4       NA        True                  max           lin               sum
# 5       NA        True                  sum           lin               min
# 6       NA        True                  sum          sqrt               min
# 7       NA        True               median           exp               min
# 8       NA        True               median           exp               sum
# 9       NA        True                  max           lin               max
# 10      NA        True                 mean           lin               max
# 11      NA        True                 mean           lin               sum
# 12      NA        True                  max           lin               min
# 13      NA        True                 mean           lin               min
# 14      NA        True               median           exp               max
# 15      NA        True                 mean          sqrt               max
# 16      NA        True                  sum           exp              diff
# 17      NA        True               median           lin              diff
# 18      NA        True                 mean           lin              diff
# 19      NA        True                 mean           exp              diff
# 20      NA        True                  max           lin              diff
# 21      NA        True               median           lin               max
# 22      NA        True                 mean          sqrt              diff
# 23      NA        True                  max           exp              diff
# 24      NA        True                  max          sqrt              diff
# 25      NA        True               median          sqrt              diff
# 26      NA        True               median           exp              diff
# 27      NA        True                 mean          sqrt               sum
# 28      NA        True                  sum           lin              diff
# 29      NA        True                 mean          sqrt               min
# 30      NA        True                  sum          sqrt              diff
# 31      NA        True                  max          sqrt               max
# 32      NA        True               median          sqrt               min
# 33      NA        True               median           lin               min
# 34      NA        True                 mean           exp               min
# 35      NA        True               median          sqrt               max
# 36      NA        True                 mean           exp               max
# 37      NA        True               median           lin               sum
# 38      NA        True                  max           exp               min
# 39      NA        True                  max          sqrt               min
# 40      NA        True               median          sqrt               sum
# 41      NA        True                 mean           exp               sum
# 42      NA        True                  max           exp               max
# 43      NA        True                  max          sqrt               sum
# 44      NA        True                  max           exp               sum
# 45      NA        True                  sum           exp               max
# 46      NA        True                  sum           exp               min
# 47      NA        True                  sum           exp               sum
#
#          rank
# 0   16.315500
# 1   16.897454
# 2   20.022483
# 3   20.598726
# 4   20.880383
# 5   22.167137
# 6   22.231461
# 7   23.280017
# 8   23.288852
# 9   23.604496
# 10  24.126215
# 11  25.524009
# 12  25.812959
# 13  26.769720
# 14  28.146487
# 15  28.980865
# 16  29.364789
# 17  29.497605
# 18  29.572528
# 19  29.909967
# 20  30.033813
# 21  30.077272
# 22  30.097401
# 23  30.159957
# 24  30.421467
# 25  30.542482
# 26  30.722721
# 27  32.503813
# 28  32.551237
# 29  32.586833
# 30  33.384946
# 31  33.799752
# 32  34.450246
# 33  35.300280
# 34  35.334380
# 35  36.146917
# 36  37.867346
# 37  38.835741
# 38  38.854439
# 39  39.641265
# 40  39.678154
# 41  39.848374
# 42  41.505222
# 43  41.508617
# 44  44.877141
# 45  48.188457
# 46  49.030246
# 47  51.478341

# %%
df.groupby(['feature', 'time_aware'])['rank'].mean().sort_values().reset_index()
# Out:
#   feature  time_aware       rank
# 0      sp       False  12.800830
# 1      NA        True  31.592052
# 2      AA        True  31.627441
# 3      aa       False  42.112274

# %%
df.groupby(['time_strategy'])['rank'].mean().sort_values().reset_index()
# Out:
#   time_strategy       rank
# 0           lin  27.264865
# 1          sqrt  31.498256
# 2           exp  36.034269
